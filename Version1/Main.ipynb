# %%
import pandas as pd
import numpy as np

# %%
products = {
    '0tovar':{
        'article_number': '0tovar',
        'title': 'Шариковая ручка "PARKER"',
        'quantity': 100,
        'price': 75480,
        'discounts': 20,
        'url_tovar': 'https://www.parkerrussia.ru/pens/duofold/PR20B-MLT53/'},

    '1tovar':{
        'article_number': '1tovar',
        'title': 'Перьевая ручка "PARKER"',
        'quantity': 100,
        'price': '200000',
        'discounts': 0,
        'url_tovar': 'https://pen-parker.ru/fountains/parker-duofold-2123549/'},
    
    '2tovar':{
        'article_number': '2tovar',
        'title': 'Ручка школьника',
        'quantity': 100,
        'price': '70',
        'discounts': 0,
        'url_tovar': 'https://www.ozon.ru/product/ruchka-lego-918586094/?asb2=ZiB0lHfB6UzaxePKIo6Jo77phqNBi8Dbiuz5Q-w8rCcRCTpZUmss_gDvoh0BuMZv&avtc=1&avte=2&avts=1680357851&keywords=ручки+шариковые&sh=iNe1bzckrQ'},

    '3tovar':{
        'article_number': '3tovar',
        'title': 'Карандаш механический "Bruno Visconti"',
        'quantity': 100,
        'price': '52',
        'discounts': 0,
        'url_tovar': 'https://leonardo.ru/ishop/group_67541861234/'},
        
    '4tovar':{
        'article_number': '4tovar',
        'title': 'Ластик для чернографитных карандашей "KOH-I-NOOR Hardtmuth"',
        'quantity': 100,
        'price': '117',
        'discounts': 10,
        'url_tovar': 'https://leonardo.ru/ishop/good_5040500583/'},

    '5tovar':{
        'article_number': '5tovar',
        'title': 'Карандаш корректирующий "Edding"',
        'quantity': 100,
        'price': '260',
        'discounts': 0,
        'url_tovar': 'https://leonardo.ru/ishop/good_31744315742/'},
    
    '6tovar':{
        'article_number': '6tovar',
        'title': 'Клей-карандаш "PRYM"',
        'quantity': 375,
        'price': '84',
        'discounts': 0,
        'url_tovar': 'https://leonardo.ru/ishop/good_209767311/'},
    
    '7tovar':{
        'article_number': '7tovar',
        'title': 'Маркер перманентный "Pentel"',
        'quantity': 840,
        'price': '38',
        'discounts': 0,
        'url_tovar': 'https://leonardo.ru/ishop/good_73277167744/'},

    '8tovar':{
        'article_number': '8tovar',
        'title': 'Маркер акриловый "PEBEO"',
        'quantity': 100,
        'price': '275',
        'discounts':15,
        'url_tovar': 'https://leonardo.ru/ishop/group_35861226922/'},

    '9tovar':{
        'article_number': '9tovar',
        'title': 'Декоративная ручка "Sakura"',
        'quantity': 100,
        'price': '203',
        'discounts': 0,
        'url_tovar': 'https://leonardo.ru/ishop/good_21808617932/'},

    '10tovar':{
        'article_number': '10tovar',
        'title': 'Маркер лаковый "Edding"',
        'quantity': 100,
        'price': '622',
        'discounts': 50,
        'url_tovar': 'https://leonardo.ru/ishop/good_74180313104/'}
}

# %%
products_df = pd.DataFrame(products)

products_df
# Out:
#                                                            0tovar  \
# article_number                                             0tovar
# title                                    Шариковая ручка "PARKER"
# quantity                                                      100
# price                                                       75480
# discounts                                                      20
# url_tovar       https://www.parkerrussia.ru/pens/duofold/PR20B...
#
#                                                            1tovar  \
# article_number                                             1tovar
# title                                     Перьевая ручка "PARKER"
# quantity                                                      100
# price                                                      200000
# discounts                                                       0
# url_tovar       https://pen-parker.ru/fountains/parker-duofold...
#
#                                                            2tovar  \
# article_number                                             2tovar
# title                                             Ручка школьника
# quantity                                                      100
# price                                                          70
# discounts                                                       0
# url_tovar       https://www.ozon.ru/product/ruchka-lego-918586...
#
#                                                       3tovar  \
# article_number                                        3tovar
# title                 Карандаш механический "Bruno Visconti"
# quantity                                                 100
# price                                                     52
# discounts                                                  0
# url_tovar       https://leonardo.ru/ishop/group_67541861234/
#
#                                                            4tovar  \
# article_number                                             4tovar
# title           Ластик для чернографитных карандашей "KOH-I-NO...
# quantity                                                      100
# price                                                         117
# discounts                                                      10
# url_tovar              https://leonardo.ru/ishop/good_5040500583/
#
#                                                      5tovar  \
# article_number                                       5tovar
# title                      Карандаш корректирующий "Edding"
# quantity                                                100
# price                                                   260
# discounts                                                 0
# url_tovar       https://leonardo.ru/ishop/good_31744315742/
#
#                                                    6tovar  \
# article_number                                     6tovar
# title                                Клей-карандаш "PRYM"
# quantity                                              375
# price                                                  84
# discounts                                               0
# url_tovar       https://leonardo.ru/ishop/good_209767311/
#
#                                                      7tovar  \
# article_number                                       7tovar
# title                          Маркер перманентный "Pentel"
# quantity                                                840
# price                                                    38
# discounts                                                 0
# url_tovar       https://leonardo.ru/ishop/good_73277167744/
#
#                                                       8tovar  \
# article_number                                        8tovar
# title                               Маркер акриловый "PEBEO"
# quantity                                                 100
# price                                                    275
# discounts                                                 15
# url_tovar       https://leonardo.ru/ishop/group_35861226922/
#
#                                                      9tovar  \
# article_number                                       9tovar
# title                           Декоративная ручка "Sakura"
# quantity                                                100
# price                                                   203
# discounts                                                 0
# url_tovar       https://leonardo.ru/ishop/good_21808617932/
#
#                                                     10tovar
# article_number                                      10tovar
# title                               Маркер лаковый "Edding"
# quantity                                                100
# price                                                   622
# discounts                                                50
# url_tovar       https://leonardo.ru/ishop/good_74180313104/

# %%
products_df2 = pd.DataFrame([{
        'article_number': '0tovar',
        'title': 'Шариковая ручка "PARKER"',
        'quantity': 100,
        'price': 75480,
        'discounts': 20,
        'url_tovar': 'https://www.parkerrussia.ru/pens/duofold/PR20B-MLT53/'},

    {
        'article_number': '1tovar',
        'title': 'Перьевая ручка "PARKER"',
        'quantity': 100,
        'price': 200000,
        'discounts': 0,
        'url_tovar': 'https://pen-parker.ru/fountains/parker-duofold-2123549/'},
    
    {
        'article_number': '2tovar',
        'title': 'Ручка школьника',
        'quantity': 100,
        'price': 70,
        'discounts': 0,
        'url_tovar': 'https://www.ozon.ru/product/ruchka-lego-918586094/?asb2=ZiB0lHfB6UzaxePKIo6Jo77phqNBi8Dbiuz5Q-w8rCcRCTpZUmss_gDvoh0BuMZv&avtc=1&avte=2&avts=1680357851&keywords=ручки+шариковые&sh=iNe1bzckrQ'},

    {
        'article_number': '3tovar',
        'title': 'Карандаш механический "Bruno Visconti"',
        'quantity': 100,
        'price': 52,
        'discounts': 0,
        'url_tovar': 'https://leonardo.ru/ishop/group_67541861234/'},
        
    {
        'article_number': '4tovar',
        'title': 'Ластик для чернографитных карандашей "KOH-I-NOOR Hardtmuth"',
        'quantity': 100,
        'price': 117,
        'discounts': 10,
        'url_tovar': 'https://leonardo.ru/ishop/good_5040500583/'},

    {
        'article_number': '5tovar',
        'title': 'Карандаш корректирующий "Edding"',
        'quantity': 100,
        'price': 260,
        'discounts': 0,
        'url_tovar': 'https://leonardo.ru/ishop/good_31744315742/'},
    
    {
        'article_number': '6tovar',
        'title': 'Клей-карандаш "PRYM"',
        'quantity': 375,
        'price': 84,
        'discounts': 0,
        'url_tovar': 'https://leonardo.ru/ishop/good_209767311/'},
    
    {
        'article_number': '7tovar',
        'title': 'Маркер перманентный "Pentel"',
        'quantity': 840,
        'price': 38,
        'discounts': 0,
        'url_tovar': 'https://leonardo.ru/ishop/good_73277167744/'},

    {
        'article_number': '8tovar',
        'title': 'Маркер акриловый "PEBEO"',
        'quantity': 100,
        'price': 275,
        'discounts':15,
        'url_tovar': 'https://leonardo.ru/ishop/group_35861226922/'},

    {
        'article_number': '9tovar',
        'title': 'Декоративная ручка "Sakura"',
        'quantity': 100,
        'price': 203,
        'discounts': 0,
        'url_tovar': 'https://leonardo.ru/ishop/good_21808617932/'},

    {
        'article_number': '10tovar',
        'title': 'Маркер лаковый "Edding"',
        'quantity': 100,
        'price': 622,
        'discounts': 50,
        'url_tovar': 'https://leonardo.ru/ishop/good_74180313104/'}], columns=['article_number',
                                                                               'title',
                                                                               'price',
                                                                               'discounts',
                                                                               'quantity',
                                                                               'url_tovar'])

# %%
products_df2
# Out:
#    article_number                                              title   price  \
# 0          0tovar                           Шариковая ручка "PARKER"   75480
# 1          1tovar                            Перьевая ручка "PARKER"  200000
# 2          2tovar                                    Ручка школьника      70
# 3          3tovar             Карандаш механический "Bruno Visconti"      52
# 4          4tovar  Ластик для чернографитных карандашей "KOH-I-NO...     117
# 5          5tovar                   Карандаш корректирующий "Edding"     260
# 6          6tovar                               Клей-карандаш "PRYM"      84
# 7          7tovar                       Маркер перманентный "Pentel"      38
# 8          8tovar                           Маркер акриловый "PEBEO"     275
# 9          9tovar                        Декоративная ручка "Sakura"     203
# 10        10tovar                            Маркер лаковый "Edding"     622
#
#     discounts  quantity                                          url_tovar
# 0          20       100  https://www.parkerrussia.ru/pens/duofold/PR20B...
# 1           0       100  https://pen-parker.ru/fountains/parker-duofold...
# 2           0       100  https://www.ozon.ru/product/ruchka-lego-918586...
# 3           0       100       https://leonardo.ru/ishop/group_67541861234/
# 4          10       100         https://leonardo.ru/ishop/good_5040500583/
# 5           0       100        https://leonardo.ru/ishop/good_31744315742/
# 6           0       375          https://leonardo.ru/ishop/good_209767311/
# 7           0       840        https://leonardo.ru/ishop/good_73277167744/
# 8          15       100       https://leonardo.ru/ishop/group_35861226922/
# 9           0       100        https://leonardo.ru/ishop/good_21808617932/
# 10         50       100        https://leonardo.ru/ishop/good_74180313104/

# %%
products_df2.to_csv('products.csv', index=False)

# %%
test = pd.read_csv('products.csv')

# %%
test.head()
# Out:
#   article_number                                              title   price  \
# 0         0tovar                           Шариковая ручка "PARKER"   75480
# 1         1tovar                            Перьевая ручка "PARKER"  200000
# 2         2tovar                                    Ручка школьника      70
# 3         3tovar             Карандаш механический "Bruno Visconti"      52
# 4         4tovar  Ластик для чернографитных карандашей "KOH-I-NO...     117
#
#    discounts  quantity                                          url_tovar
# 0         20       100  https://www.parkerrussia.ru/pens/duofold/PR20B...
# 1          0       100  https://pen-parker.ru/fountains/parker-duofold...
# 2          0       100  https://www.ozon.ru/product/ruchka-lego-918586...
# 3          0       100       https://leonardo.ru/ishop/group_67541861234/
# 4         10       100         https://leonardo.ru/ishop/good_5040500583/

# %% [markdown]
# ща надо создать историю

# %%
file_history = 'System programming\TeleBot\history.csv'


a_df = pd.DataFrame([{'Id': 0,
                      'User_id': 'test', 
                      'User_first_name': 'test', 
                      'User_last_name': 'test', 
                      'Username': 'test'}])

# %%
a_df.head()
# Out:
#    Id User_id User_first_name User_last_name Username
# 0   0    test            test           test     test

# %%
a_df.to_csv('history.csv', index=False)

# %%
import pathlib
from pathlib import Path
work_path = pathlib.Path.cwd()
print(work_path)

# %%
# Out:
# c:\Users\drdov\Desktop\Tele-gnida-bot\Version1
